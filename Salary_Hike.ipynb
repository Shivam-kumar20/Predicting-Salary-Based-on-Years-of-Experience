# %% [markdown]
# ### Salary_Hike_Predicting_model

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'C:/Users/shivam.kumar/Videos/CodeWithHarry/18 Nov Assignment/Project - 1&2_ Simple_Reg/Salary_Data.csv'

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
df.columns
x1=np.array(df.YearsExperience).reshape(-1,1)
y1=np.array(df.Salary).reshape(-1,1)

# %% [markdown]
# ### EDA

# %%
df.plot(x='YearsExperience',y='Salary',kind = 'line')
# Out:
# <Axes: xlabel='YearsExperience'>

# %%
df.plot(x='YearsExperience',y='Salary',kind = 'scatter')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
df.plot(x='YearsExperience',y='Salary',kind = 'bar')
# Out:
# <Axes: xlabel='YearsExperience'>

# %%
sns.heatmap(df.corr(),annot = True,vmin=-1)
# Out:
# <Axes: >

# %%
sns.lineplot(x=df.YearsExperience,
             y=df.Salary,
#              hue=df.Salary,
             c='r',
             ls="--",
             lw = 2,
             marker = "*",
             markersize =10,
            mec = 'k',
            mfc = 'b')
plt.show()

# %%
sns.scatterplot(x=df.YearsExperience,
             y=df.Salary,
               hue=df.Salary)
plt.show()

# %% [markdown]
# ### Creating the salary prediction model the use of employee experience

# %%
df.shape
# Out:
# (30, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
x=df.YearsExperience.values.reshape(-1,1)
# x=np.array(x)
y=df.Salary.values.reshape(-1,1)
# y=np.array(y)

# %%
# Importing Libraries

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.15,random_state = 12)

lr = LinearRegression()

model = lr.fit(x_train,y_train)
pred = lr.predict(x_test)

accur = r2_score(y_test,pred)
error = mean_squared_error(y_test,pred)

# %%
print(f'The r2_score y_test and y-predict is {accur}')
# Out:
# The r2_score y_test and y-predict is 0.9366671674339628
